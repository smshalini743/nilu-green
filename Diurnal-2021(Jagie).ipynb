# %%
#diurnal variation - Jagiellońska, 2021

#january
import pandas as pd
df = pd.read_csv("./Jagiellońska/2021/Jagie-PM2.5-Jan.csv")
new = df["PM2.5"].str.split(';', 2, expand = True)
df["Date"] = new[0]
df["PM2.5"] = new[2]
PM = []
PM = df["PM2.5"].str.replace('"','')

for i in range(0,len(PM)):
    if PM[i] != '':
        PM[i] = int(PM[i])
    else:
        PM[i] = 0 

Date1 = []
Date1 = df["Date"]
Date1 = list(Date1)

Date1x = []
for j in range(0,len(Date1)):
    abc = Date1[j]
    abcd = abc.replace(abc[5:11], '')          
    Date1x.append(abcd)
Date1x

zippedlist = list(zip(Date1x,PM))
dfobj = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfobj

dfin = dfobj.groupby(['hourly']).mean()
dfint = dfin.reset_index()
print(dfint)
x = dfint['hourly']
yjan = dfint['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yjan, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Jagiellońska - Diurnal Variation(January,2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  54.666667
# 1   01:30  55.133333
# 2   02:30  55.566667
# 3   03:30  50.600000
# 4   04:30  50.466667
# 5   05:30  49.300000
# 6   06:30  45.100000
# 7   07:30  40.500000
# 8   08:30  37.800000
# 9   09:30  37.533333
# 10  10:30  37.900000
# 11  11:30  39.233333
# 12  12:30  38.533333
# 13  13:30  39.100000
# 14  14:30  38.300000
# 15  15:30  36.966667
# 16  16:30  36.666667
# 17  17:30  36.200000
# 18  18:30  36.566667
# 19  19:30  38.766667
# 20  20:30  40.400000
# 21  21:30  43.233333
# 22  22:30  46.733333
# 23  23:30  53.400000

# %%
#february

dffeb = pd.read_csv("./Jagiellońska/2021/Jagie-PM2.5-Feb.csv")
newfeb = dffeb["PM2.5"].str.split(';', 2, expand = True)
dffeb["Date"] = newfeb[0]
dffeb["PM2.5"] = newfeb[2]
PMfeb = []
PMfeb = dffeb["PM2.5"].str.replace('"','')

for i in range(0,len(PMfeb)):
    if PMfeb[i] != '':
        PMfeb[i] = int(PMfeb[i])
    else:
        PMfeb[i] = 0 


Date2 = []
Date2 = dffeb["Date"]
Date2 = list(Date2)

Date2x = []
for j in range(0,len(Date2)):
    abc = Date2[j]
    abcd = abc.replace(abc[5:11], '')          
    Date2x.append(abcd)
Date2x

zippedlist = list(zip(Date2x,PMfeb))
dffebr = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dffebr

dffebru = dffebr.groupby(['hourly']).mean()
dffebrua = dffebru.reset_index()
print(dffebrua)
x = dffebrua['hourly']
yfeb = dffebrua['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yfeb, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Jagiellońska - Diurnal Variation(February,2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  50.814815
# 1   01:30  53.592593
# 2   02:30  53.555556
# 3   03:30  54.555556
# 4   04:30  55.962963
# 5   05:30  55.777778
# 6   06:30  52.111111
# 7   07:30  49.481481
# 8   08:30  47.333333
# 9   09:30  46.518519
# 10  10:30  48.740741
# 11  11:30  46.666667
# 12  12:30  42.444444
# 13  13:30  38.185185
# 14  14:30  34.666667
# 15  15:30  32.111111
# 16  16:30  30.777778
# 17  17:30  29.703704
# 18  18:30  29.296296
# 19  19:30  29.444444
# 20  20:30  33.000000
# 21  21:30  36.925926
# 22  22:30  40.111111
# 23  23:30  45.851852

# %%
#march
dfmar = pd.read_csv("./Jagiellońska/2021/Jagie-PM2.5-Mar.csv")
newmar = dfmar["PM2.5"].str.split(';', 2, expand = True)
dfmar["Date"] = newmar[0]
dfmar["PM2.5"] = newmar[2]
PMmar = []
PMmar = dfmar["PM2.5"].str.replace('"','')
for i in range(0,len(PMmar)):
    if PMmar[i] != '':
        PMmar[i] = int(PMmar[i])
    else:
        PMmar[i] = 0 
PMmar
Date3 = []
Date3 = dfmar["Date"]
Date3 = list(Date3)

Date3x = []
for j in range(0,len(Date3)):
    abc = Date3[j]
    abcd = abc.replace(abc[5:11], '')          
    Date3x.append(abcd)
Date3x

zippedlist = list(zip(Date3x,PMmar))
dfmarch = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfmarch

dfmarch1 = dfmarch.groupby(['hourly']).mean()
dfmarch2 = dfmarch1.reset_index()
print(dfmarch2)
x = dfmarch2['hourly']
ymar = dfmarch2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,ymar, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Jagiellońska - Diurnal Variation(March,2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  44.500000
# 1   01:30  45.033333
# 2   02:30  46.400000
# 3   03:30  43.896552
# 4   04:30  36.566667
# 5   05:30  31.200000
# 6   06:30  28.866667
# 7   07:30  27.600000
# 8   08:30  27.000000
# 9   09:30  26.933333
# 10  10:30  28.366667
# 11  11:30  28.066667
# 12  12:30  24.433333
# 13  13:30  21.866667
# 14  14:30  19.033333
# 15  15:30  17.233333
# 16  16:30  16.300000
# 17  17:30  16.166667
# 18  18:30  15.633333
# 19  19:30  16.333333
# 20  20:30  19.200000
# 21  21:30  23.466667
# 22  22:30  32.000000
# 23  23:30  41.300000

# %%
#april
dfapr = pd.read_csv("./Jagiellońska/2021/Jagie-PM2.5-Apr.csv")
newapr = dfapr["PM2.5"].str.split(';', 2, expand = True)
dfapr["Date"] = newapr[0]
dfapr["PM2.5"] = newapr[2]
PMapr = []
PMapr = dfapr["PM2.5"].str.replace('"','')
PMapr

for i in range(0,len(PMapr)):
    if PMapr[i] != '':
        PMapr[i] = int(PMapr[i])
    else:
        PMapr[i] = 0 

Date4 = []
Date4 = dfapr["Date"]
Date4 = list(Date4)

Date4x = []
for j in range(0,len(Date4)):
    abc = Date4[j]
    abcd = abc.replace(abc[5:11], '')          
    Date4x.append(abcd)
Date4x

zippedlist = list(zip(Date4x,PMapr))
dfapril = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfapril

dfapril1 = dfapril.groupby(['hourly']).mean()
dfapril2 = dfapril1.reset_index()
print(dfapril2)
x = dfapril2['hourly']
yapr = dfapril2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yapr, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Jagiellońska - Diurnal Variation(April,2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  32.482759
# 1   01:30  33.034483
# 2   02:30  34.862069
# 3   03:30  34.620690
# 4   04:30  33.034483
# 5   05:30  29.896552
# 6   06:30  28.931034
# 7   07:30  25.655172
# 8   08:30  25.724138
# 9   09:30  26.586207
# 10  10:30  23.551724
# 11  11:30  19.551724
# 12  12:30  16.655172
# 13  13:30  13.793103
# 14  14:30  11.896552
# 15  15:30  11.103448
# 16  16:30  10.241379
# 17  17:30   9.965517
# 18  18:30  10.482759
# 19  19:30  11.103448
# 20  20:30  12.689655
# 21  21:30  14.551724
# 22  22:30  19.931034
# 23  23:30  26.103448

# %%
#may

dfmay = pd.read_csv("./Jagiellońska/2021/Jagie-PM2.5-May.csv")
newmay = dfmay["PM2.5"].str.split(';', 2, expand = True)
dfmay["Date"] = newmay[0]
dfmay["PM2.5"] = newmay[2]
PMmay = []
PMmay = dfmay["PM2.5"].str.replace('"','')

for i in range(0,len(PMmay)):
    if PMmay[i] != '':
        PMmay[i] = int(PMmay[i])
    else:
        PMmay[i] = 0 
PMmay

Date5 = []
Date5 = dfmay["Date"]
Date5 = list(Date5)

Date5x = []
for j in range(0,len(Date5)):
    abc = Date5[j]
    abcd = abc.replace(abc[5:11], '')          
    Date5x.append(abcd)
Date5x

zippedlist = list(zip(Date5x,PMmay))
dfmay1 = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfmay1

dfmay2 = dfmay1.groupby(['hourly']).mean()
dfmay3 = dfmay2.reset_index()
print(dfmay3)

x = dfmay3['hourly']
ymay = dfmay3['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,ymay, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Jagiellońska - Diurnal Variation(May,2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  12.866667
# 1   01:30  14.133333
# 2   02:30  14.100000
# 3   03:30  13.933333
# 4   04:30  13.500000
# 5   05:30  13.166667
# 6   06:30  13.633333
# 7   07:30  14.233333
# 8   08:30  14.166667
# 9   09:30  13.900000
# 10  10:30  12.800000
# 11  11:30  10.933333
# 12  12:30   9.166667
# 13  13:30   7.566667
# 14  14:30   6.833333
# 15  15:30   6.333333
# 16  16:30   6.766667
# 17  17:30   6.766667
# 18  18:30   7.133333
# 19  19:30   7.033333
# 20  20:30   6.766667
# 21  21:30   6.966667
# 22  22:30   8.600000
# 23  23:30  10.866667

# %%
#june
dfjun = pd.read_csv("./Jagiellońska/2021/Jagie-PM2.5-Jun.csv")
newjun = dfjun["PM2.5"].str.split(';', 2, expand = True)
dfjun["Date"] = newjun[0]
dfjun["PM2.5"] = newjun[2]
PMjun = []
PMjun = dfjun["PM2.5"].str.replace('"','')

for i in range(0,len(PMjun)):
    if PMjun[i] != '':
        PMjun[i] = int(PMjun[i])
    else:
        PMjun[i] = 0

Date6 = []
Date6 = dfjun["Date"]
Date6 = list(Date6)

Date6x = []
for j in range(0,len(Date6)):
    abc = Date6[j]
    abcd = abc.replace(abc[5:11], '')          
    Date6x.append(abcd)

zippedlist = list(zip(Date6x,PMjun))
dfjune = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfjune

dfjune1 = dfjune.groupby(['hourly']).mean()
dfjune2 = dfjune1.reset_index()
print(dfjune2)

x = dfjune2['hourly']
yjun = dfjune2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yjun, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Jagiellońska - Diurnal Variation(June,2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  12.000000
# 1   01:30  14.862069
# 2   02:30  16.482759
# 3   03:30  17.137931
# 4   04:30  17.586207
# 5   05:30  17.793103
# 6   06:30  17.724138
# 7   07:30  17.655172
# 8   08:30  17.517241
# 9   09:30  16.413793
# 10  10:30  14.448276
# 11  11:30  12.655172
# 12  12:30  11.413793
# 13  13:30   9.896552
# 14  14:30   8.758621
# 15  15:30   8.103448
# 16  16:30   7.931034
# 17  17:30   8.000000
# 18  18:30   7.689655
# 19  19:30   7.724138
# 20  20:30   7.448276
# 21  21:30   7.448276
# 22  22:30   7.482759
# 23  23:30   9.517241

# %%
#july
dfjul = pd.read_csv("./Jagiellońska/2021/Jagie-PM2.5-Jul.csv")
newjul = dfjul["PM2.5"].str.split(';', 2, expand = True)
dfjul["Date"] = newjul[0]
dfjul["PM2.5"] = newjul[2]
PMjul = []
PMjul = dfjul["PM2.5"].str.replace('"','')

for i in range(0,len(PMjul)):
    if PMjul[i] != '':
        PMjul[i] = int(PMjul[i])
    else:
        PMjul[i] = 0

Date7 = []
Date7 = dfjul["Date"]
Date7 = list(Date7)

Date7x = []
for j in range(0,len(Date7)):
    abc = Date7[j]
    abcd = abc.replace(abc[5:11], '')          
    Date7x.append(abcd)

zippedlist = list(zip(Date7x,PMjul))
dfjuly = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfjuly

dfjuly1 = dfjuly.groupby(['hourly']).mean()
dfjuly2 = dfjuly1.reset_index()
print(dfjuly2)

x = dfjuly2['hourly']
yjul = dfjuly2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yjul, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Jagiellońska - Diurnal Variation(July,2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  13.300000
# 1   01:30  14.966667
# 2   02:30  14.466667
# 3   03:30  14.566667
# 4   04:30  15.133333
# 5   05:30  15.366667
# 6   06:30  15.800000
# 7   07:30  15.833333
# 8   08:30  16.033333
# 9   09:30  16.466667
# 10  10:30  15.300000
# 11  11:30  13.900000
# 12  12:30  13.266667
# 13  13:30  12.833333
# 14  14:30  11.600000
# 15  15:30  11.033333
# 16  16:30  10.400000
# 17  17:30  10.200000
# 18  18:30   9.733333
# 19  19:30   9.533333
# 20  20:30   9.666667
# 21  21:30   8.900000
# 22  22:30   9.333333
# 23  23:30  11.166667

# %%
#august
dfaug = pd.read_csv("./Jagiellońska/2021/Jagie-PM2.5-Aug.csv")
newaug = dfaug["PM2.5"].str.split(';', 2, expand = True)
dfaug["Date"] = newaug[0]
dfaug["PM2.5"] = newaug[2]
PMaug = []
PMaug = dfaug["PM2.5"].str.replace('"','')

for i in range(0,len(PMaug)):
    if PMaug[i] != '':
        PMaug[i] = int(PMaug[i])
    else:
        PMaug[i] = 0

Date8 = []
Date8 = dfaug["Date"]
Date8 = list(Date8)

Date8x = []
for j in range(0,len(Date8)):
    abc = Date8[j]
    abcd = abc.replace(abc[5:11], '')          
    Date8x.append(abcd)

zippedlist = list(zip(Date8x,PMaug))
dfaugust = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfaugust

dfaugust1 = dfaugust.groupby(['hourly']).mean()
dfaugust2 = dfaugust1.reset_index()
print(dfaugust2)

x = dfaugust2['hourly']
yaug = dfaugust2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yaug, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Jagiellońska - Diurnal Variation(August,2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  11.400000
# 1   01:30  12.566667
# 2   02:30  13.233333
# 3   03:30  13.366667
# 4   04:30  13.433333
# 5   05:30  13.233333
# 6   06:30  13.633333
# 7   07:30  13.566667
# 8   08:30  13.500000
# 9   09:30  13.666667
# 10  10:30  13.400000
# 11  11:30  13.133333
# 12  12:30  11.700000
# 13  13:30  10.066667
# 14  14:30   8.833333
# 15  15:30   7.400000
# 16  16:30   6.633333
# 17  17:30   6.100000
# 18  18:30   5.966667
# 19  19:30   5.933333
# 20  20:30   6.133333
# 21  21:30   6.466667
# 22  22:30   7.600000
# 23  23:30   9.666667

# %%
#september
dfsep = pd.read_csv("./Jagiellońska/2021/Jagie-PM2.5-Sept.csv")
newsep = dfsep["PM2.5"].str.split(';', 2, expand = True)
dfsep["Date"] = newsep[0]
dfsep["PM2.5"] = newsep[2]
PMsep = []
PMsep = dfsep["PM2.5"].str.replace('"','')

for i in range(0,len(PMsep)):
    if PMsep[i] != '':
        PMsep[i] = int(PMsep[i])
    else:
        PMsep[i] = 0

Date9 = []
Date9 = dfsep["Date"]
Date9 = list(Date9)

Date9x = []
for j in range(0,len(Date9)):
    abc = Date9[j]
    abcd = abc.replace(abc[5:11], '')          
    Date9x.append(abcd)

zippedlist = list(zip(Date9x,PMsep))
dfseptember = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfseptember

dfseptember1 = dfseptember.groupby(['hourly']).mean()
dfseptember2 = dfseptember1.reset_index()
print(dfseptember2)

x = dfseptember2['hourly']
ysep = dfseptember2['conc']
# print(x)
# print(ysep)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,ysep, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Jagiellońska - Diurnal Variation(September,2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  11.103448
# 1   01:30  11.275862
# 2   02:30  11.793103
# 3   03:30  12.206897
# 4   04:30  11.620690
# 5   05:30  11.103448
# 6   06:30  11.000000
# 7   07:30  10.758621
# 8   08:30  10.724138
# 9   09:30  11.206897
# 10  10:30  10.896552
# 11  11:30  10.034483
# 12  12:30   8.241379
# 13  13:30   6.862069
# 14  14:30   6.241379
# 15  15:30   5.137931
# 16  16:30   4.965517
# 17  17:30   4.724138
# 18  18:30   4.827586
# 19  19:30   4.827586
# 20  20:30   4.862069
# 21  21:30   5.620690
# 22  22:30   6.931034
# 23  23:30   9.793103

# %%
#october
dfoct = pd.read_csv("./Jagiellońska/2021/Jagie-PM2.5-Oct.csv")
newoct = dfoct["PM2.5"].str.split(';', 2, expand = True)
dfoct["Date"] = newoct[0]
dfoct["PM2.5"] = newoct[2]
PMoct = []
PMoct = dfoct["PM2.5"].str.replace('"','')

for i in range(0,len(PMoct)):
    if PMoct[i] != '':
        PMoct[i] = int(PMoct[i])
    else:
        PMoct[i] = 0

Date10 = []
Date10 = dfoct["Date"]
Date10 = list(Date10)

Date10x = []
for j in range(0,len(Date10)):
    abc = Date10[j]
    abcd = abc.replace(abc[5:11], '')          
    Date10x.append(abcd)

zippedlist = list(zip(Date10x,PMoct))
dfoctober = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfoctober

dfoctober1 = dfoctober.groupby(['hourly']).mean()
dfoctober2 = dfoctober1.reset_index()
print(dfoctober2)

x = dfoctober2['hourly']
yoct = dfoctober2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yoct, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Jagiellońska - Diurnal Variation(October,2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  27.766667
# 1   01:30  26.533333
# 2   02:30  25.900000
# 3   03:30  24.166667
# 4   04:30  23.300000
# 5   05:30  21.866667
# 6   06:30  21.300000
# 7   07:30  21.166667
# 8   08:30  20.166667
# 9   09:30  20.466667
# 10  10:30  20.600000
# 11  11:30  19.666667
# 12  12:30  17.733333
# 13  13:30  16.000000
# 14  14:30  14.266667
# 15  15:30  12.433333
# 16  16:30  11.300000
# 17  17:30  11.033333
# 18  18:30  10.733333
# 19  19:30  12.033333
# 20  20:30  14.233333
# 21  21:30  18.433333
# 22  22:30  23.933333
# 23  23:30  27.300000

# %%
#november
dfnov = pd.read_csv("./Jagiellońska/2021/Nov-Jagie.csv")
newnov = dfnov["From;To;ID 86697 - PM2.5"].str.split(';', 2, expand = True)
dfnov["Date"] = newnov[0]
dfnov["PM2.5"] = newnov[2]
PMnov = []
PMnov = dfnov["PM2.5"].str.replace('"','')

for i in range(0,len(PMnov)):
    if PMnov[i] != '':
        PMnov[i] = int(PMnov[i])
    else:
        PMnov[i] = 0

Date11 = []
Date11 = dfnov["Date"]
Date11 = list(Date11)

Date11x = []
for j in range(0,len(Date11)):
    abc = Date11[j]
    abcd = abc.replace(abc[5:11], '')          
    Date11x.append(abcd)

zippedlist = list(zip(Date11x,PMnov))
dfnovember = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
#print(dfnovember)

dfnovember1 = dfnovember.groupby(['hourly']).mean()
dfnovember2 = dfnovember1.reset_index()
#print(dfnovember2)

x = dfnovember2['hourly']
ynov = dfnovember2['conc']
# print(x)
# print(ynov)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,ynov, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Jagiellońska - Diurnal Variation(November,2021)")
plt.show()

# %%
#december
dfdec = pd.read_csv("./Jagiellońska/2021/Dec-Jagie.csv")
newdec = dfdec["From;To;ID 86697 - PM2.5"].str.split(';', 2, expand = True)
dfdec["Date"] = newdec[0]
dfdec["PM2.5"] = newdec[2]
PMdec = []
PMdec = dfdec["PM2.5"].str.replace('"','')

for i in range(0,len(PMdec)):
    if PMdec[i] != '':
        PMdec[i] = int(PMdec[i])
    else:
        PMdec[i] = 0

Date12 = []
Date12 = dfdec["Date"]
Date12 = list(Date12)

Date12x = []
for j in range(0,len(Date12)):
    abc = Date12[j]
    abcd = abc.replace(abc[5:11], '')          
    Date12x.append(abcd)

zippedlist = list(zip(Date12x,PMdec))
dfdecember = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfdecember

dfdecember1 = dfdecember.groupby(['hourly']).mean()
dfdecember2 = dfdecember1.reset_index()
#print(dfdecember2)

x = dfdecember2['hourly']
ydec = dfdecember2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,ydec, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Jagiellońska - Diurnal Variation(December,2021)")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yjan, label = 'Jan')
plt.plot(x,yfeb, label = 'Feb')
plt.plot(x,ymar, label = 'Mar')
plt.plot(x,yapr, label = 'Apr')
plt.plot(x,ymay, label = 'May')
plt.plot(x,yjun, label = 'June')
plt.plot(x,yjul, label = 'July')
plt.plot(x,yaug, label = 'Aug')
plt.plot(x,ysep, label = 'Sept')
plt.plot(x,yoct, label = 'Oct')
plt.plot(x,ynov,color = 'm', label = 'Nov')
plt.plot(x,ydec,color = 'k', label = 'Dec')

plt.xlabel('Hour of the day')
plt.ylabel('PM2.5 conc')
plt.title('Diurnal variation(Sensor Jagiellońska) - 2021')
plt.legend()
plt.show()
