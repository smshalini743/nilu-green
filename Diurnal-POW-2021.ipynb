# %%
#diurnal variation of Polskiej Organizacji Wojskowej - 2021

#january

import pandas as pd
df = pd.read_csv("./Polskiej Organizacji Wojskowej/2021/Airly-report-2021-01-01T00_00-2021-01-31T00_00.csv")
new = df["From;To;ID 31103 - PM2.5"].str.split(';', 2, expand = True)
df["Date"] = new[0]
df["PM2.5"] = new[2]
PM = []
PM = df["PM2.5"].str.replace('"','')

for i in range(0,len(PM)):
    if PM[i] != '':
        PM[i] = int(PM[i])
    else:
        PM[i] = 0 

Date1 = []
Date1 = df["Date"]
Date1 = list(Date1)

Date1x = []
for j in range(0,len(Date1)):
    abc = Date1[j]
    abcd = abc.replace(abc[5:11], '')          
    Date1x.append(abcd)
Date1x

zippedlist = list(zip(Date1x,PM))
dfobj = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfobj

dfin = dfobj.groupby(['hourly']).mean()
dfint = dfin.reset_index()
print(dfint)
x = dfint['hourly']
yjan = dfint['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yjan, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Polskiej Organizacji Wojskowej - Diurnal Variation(January-2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  60.266667
# 1   01:30  62.933333
# 2   02:30  61.700000
# 3   03:30  58.400000
# 4   04:30  59.566667
# 5   05:30  59.566667
# 6   06:30  53.600000
# 7   07:30  45.400000
# 8   08:30  42.100000
# 9   09:30  44.000000
# 10  10:30  44.033333
# 11  11:30  44.866667
# 12  12:30  44.366667
# 13  13:30  42.833333
# 14  14:30  41.200000
# 15  15:30  39.633333
# 16  16:30  39.066667
# 17  17:30  39.700000
# 18  18:30  40.333333
# 19  19:30  44.300000
# 20  20:30  47.333333
# 21  21:30  49.233333
# 22  22:30  53.266667
# 23  23:30  58.800000

# %%
#february
dffeb = pd.read_csv("./Polskiej Organizacji Wojskowej/2021/Airly-report-2021-02-01T00_00-2021-02-28T00_00.csv")
newfeb = dffeb["From;To;ID 31103 - PM2.5"].str.split(';', 2, expand = True)
dffeb["Date"] = newfeb[0]
dffeb["PM2.5"] = newfeb[2]
PMfeb = []
PMfeb = dffeb["PM2.5"].str.replace('"','')

for i in range(0,len(PMfeb)):
    if PMfeb[i] != '':
        PMfeb[i] = int(PMfeb[i])
    else:
        PMfeb[i] = 0 


Date2 = []
Date2 = dffeb["Date"]
Date2 = list(Date2)

Date2x = []
for j in range(0,len(Date2)):
    abc = Date2[j]
    abcd = abc.replace(abc[5:11], '')          
    Date2x.append(abcd)
Date2x

zippedlist = list(zip(Date2x,PMfeb))
dffebr = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dffebr

dffebru = dffebr.groupby(['hourly']).mean()
dffebrua = dffebru.reset_index()
print(dffebrua)
x = dffebrua['hourly']
yfeb = dffebrua['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yfeb, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Polskiej Organizacji Wojskowej - Diurnal Variation(February-2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  52.370370
# 1   01:30  58.296296
# 2   02:30  62.740741
# 3   03:30  63.518519
# 4   04:30  58.074074
# 5   05:30  56.481481
# 6   06:30  51.333333
# 7   07:30  50.962963
# 8   08:30  48.851852
# 9   09:30  48.629630
# 10  10:30  52.111111
# 11  11:30  49.407407
# 12  12:30  43.629630
# 13  13:30  38.592593
# 14  14:30  35.296296
# 15  15:30  34.037037
# 16  16:30  33.222222
# 17  17:30  31.888889
# 18  18:30  32.111111
# 19  19:30  31.111111
# 20  20:30  36.407407
# 21  21:30  39.666667
# 22  22:30  46.740741
# 23  23:30  50.851852

# %%
#march

dfmar = pd.read_csv("./Polskiej Organizacji Wojskowej/2021/Airly-report-2021-03-01T00_00-2021-03-31T00_00.csv")
newmar = dfmar["From;To;ID 31103 - PM2.5"].str.split(';', 2, expand = True)
dfmar["Date"] = newmar[0]
dfmar["PM2.5"] = newmar[2]
PMmar = []
PMmar = dfmar["PM2.5"].str.replace('"','')
for i in range(0,len(PMmar)):
    if PMmar[i] != '':
        PMmar[i] = int(PMmar[i])
    else:
        PMmar[i] = 0 
PMmar
Date3 = []
Date3 = dfmar["Date"]
Date3 = list(Date3)

Date3x = []
for j in range(0,len(Date3)):
    abc = Date3[j]
    abcd = abc.replace(abc[5:11], '')          
    Date3x.append(abcd)
Date3x

zippedlist = list(zip(Date3x,PMmar))
dfmarch = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfmarch

dfmarch1 = dfmarch.groupby(['hourly']).mean()
dfmarch2 = dfmarch1.reset_index()
print(dfmarch2)
x = dfmarch2['hourly']
ymar = dfmarch2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,ymar, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Polskiej Organizacji Wojskowej - Diurnal Variation(March-2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  45.800000
# 1   01:30  46.033333
# 2   02:30  45.566667
# 3   03:30  43.000000
# 4   04:30  37.933333
# 5   05:30  33.100000
# 6   06:30  32.033333
# 7   07:30  28.466667
# 8   08:30  27.233333
# 9   09:30  28.900000
# 10  10:30  32.600000
# 11  11:30  30.200000
# 12  12:30  25.600000
# 13  13:30  22.800000
# 14  14:30  20.100000
# 15  15:30  18.933333
# 16  16:30  17.666667
# 17  17:30  17.833333
# 18  18:30  18.066667
# 19  19:30  19.066667
# 20  20:30  21.466667
# 21  21:30  26.800000
# 22  22:30  36.333333
# 23  23:30  43.566667

# %%
#april

dfapr = pd.read_csv("./Polskiej Organizacji Wojskowej/2021/Airly-report-2021-04-01T00_00-2021-04-30T00_00.csv")
newapr = dfapr["From;To;ID 31103 - PM2.5"].str.split(';', 2, expand = True)
dfapr["Date"] = newapr[0]
dfapr["PM2.5"] = newapr[2]
PMapr = []
PMapr = dfapr["PM2.5"].str.replace('"','')
PMapr

for i in range(0,len(PMapr)):
    if PMapr[i] != '':
        PMapr[i] = int(PMapr[i])
    else:
        PMapr[i] = 0 

Date4 = []
Date4 = dfapr["Date"]
Date4 = list(Date4)

Date4x = []
for j in range(0,len(Date4)):
    abc = Date4[j]
    abcd = abc.replace(abc[5:11], '')          
    Date4x.append(abcd)
Date4x

zippedlist = list(zip(Date4x,PMapr))
dfapril = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfapril

dfapril1 = dfapril.groupby(['hourly']).mean()
dfapril2 = dfapril1.reset_index()
print(dfapril2)
x = dfapril2['hourly']
yapr = dfapril2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yapr, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Polskiej Organizacji Wojskowej - Diurnal Variation(April-2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  36.379310
# 1   01:30  37.275862
# 2   02:30  34.655172
# 3   03:30  31.793103
# 4   04:30  31.068966
# 5   05:30  31.068966
# 6   06:30  28.689655
# 7   07:30  26.448276
# 8   08:30  26.724138
# 9   09:30  25.482759
# 10  10:30  22.620690
# 11  11:30  20.172414
# 12  12:30  17.275862
# 13  13:30  14.482759
# 14  14:30  12.862069
# 15  15:30  11.965517
# 16  16:30  12.172414
# 17  17:30  12.137931
# 18  18:30  12.689655
# 19  19:30  14.137931
# 20  20:30  15.482759
# 21  21:30  17.689655
# 22  22:30  22.448276
# 23  23:30  31.827586

# %%
#may

dfmay = pd.read_csv("./Polskiej Organizacji Wojskowej/2021/Airly-report-2021-05-01T00_00-2021-05-31T00_00.csv")
newmay = dfmay["From;To;ID 31103 - PM2.5"].str.split(';', 2, expand = True)
dfmay["Date"] = newmay[0]
dfmay["PM2.5"] = newmay[2]
PMmay = []
PMmay = dfmay["PM2.5"].str.replace('"','')

for i in range(0,len(PMmay)):
    if PMmay[i] != '':
        PMmay[i] = int(PMmay[i])
    else:
        PMmay[i] = 0 
PMmay

Date5 = []
Date5 = dfmay["Date"]
Date5 = list(Date5)

Date5x = []
for j in range(0,len(Date5)):
    abc = Date5[j]
    abcd = abc.replace(abc[5:11], '')          
    Date5x.append(abcd)
Date5x

zippedlist = list(zip(Date5x,PMmay))
dfmay1 = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfmay1

dfmay2 = dfmay1.groupby(['hourly']).mean()
dfmay3 = dfmay2.reset_index()
print(dfmay3)

x = dfmay3['hourly']
ymay = dfmay3['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,ymay, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Polskiej Organizacji Wojskowej - Diurnal Variation(May-2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  14.933333
# 1   01:30  15.366667
# 2   02:30  14.866667
# 3   03:30  14.966667
# 4   04:30  14.266667
# 5   05:30  14.300000
# 6   06:30  14.633333
# 7   07:30  14.966667
# 8   08:30  15.200000
# 9   09:30  13.900000
# 10  10:30  11.966667
# 11  11:30   9.866667
# 12  12:30   8.400000
# 13  13:30   7.333333
# 14  14:30   6.500000
# 15  15:30   6.333333
# 16  16:30   6.800000
# 17  17:30   7.300000
# 18  18:30   7.866667
# 19  19:30   8.666667
# 20  20:30   8.500000
# 21  21:30   9.200000
# 22  22:30  10.366667
# 23  23:30  13.500000

# %%
#june

dfjun = pd.read_csv("./Polskiej Organizacji Wojskowej/2021/Airly-report-2021-06-01T00_00-2021-06-30T00_00.csv")
newjun = dfjun["From;To;ID 31103 - PM2.5"].str.split(';', 2, expand = True)
dfjun["Date"] = newjun[0]
dfjun["PM2.5"] = newjun[2]
PMjun = []
PMjun = dfjun["PM2.5"].str.replace('"','')

for i in range(0,len(PMjun)):
    if PMjun[i] != '':
        PMjun[i] = int(PMjun[i])
    else:
        PMjun[i] = 0

Date6 = []
Date6 = dfjun["Date"]
Date6 = list(Date6)

Date6x = []
for j in range(0,len(Date6)):
    abc = Date6[j]
    abcd = abc.replace(abc[5:11], '')          
    Date6x.append(abcd)

zippedlist = list(zip(Date6x,PMjun))
dfjune = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfjune

dfjune1 = dfjune.groupby(['hourly']).mean()
dfjune2 = dfjune1.reset_index()
print(dfjune2)

x = dfjune2['hourly']
yjun = dfjune2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yjun, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Polskiej Organizacji Wojskowej - Diurnal Variation(June-2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  14.551724
# 1   01:30  17.172414
# 2   02:30  18.034483
# 3   03:30  18.310345
# 4   04:30  18.517241
# 5   05:30  18.931034
# 6   06:30  18.586207
# 7   07:30  18.551724
# 8   08:30  17.034483
# 9   09:30  13.931034
# 10  10:30  11.586207
# 11  11:30   9.689655
# 12  12:30   8.758621
# 13  13:30   8.103448
# 14  14:30   7.862069
# 15  15:30   7.620690
# 16  16:30   8.275862
# 17  17:30   8.482759
# 18  18:30   9.000000
# 19  19:30   9.103448
# 20  20:30   9.206897
# 21  21:30   9.172414
# 22  22:30   9.275862
# 23  23:30  11.068966

# %%
#july

dfjul = pd.read_csv("./Polskiej Organizacji Wojskowej/2021/Airly-report-2021-07-01T00_00-2021-07-31T00_00.csv")
newjul = dfjul["From;To;ID 31103 - PM2.5"].str.split(';', 2, expand = True)
dfjul["Date"] = newjul[0]
dfjul["PM2.5"] = newjul[2]
PMjul = []
PMjul = dfjul["PM2.5"].str.replace('"','')

for i in range(0,len(PMjul)):
    if PMjul[i] != '':
        PMjul[i] = int(PMjul[i])
    else:
        PMjul[i] = 0

Date7 = []
Date7 = dfjul["Date"]
Date7 = list(Date7)

Date7x = []
for j in range(0,len(Date7)):
    abc = Date7[j]
    abcd = abc.replace(abc[5:11], '')          
    Date7x.append(abcd)

zippedlist = list(zip(Date7x,PMjul))
dfjuly = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfjuly

dfjuly1 = dfjuly.groupby(['hourly']).mean()
dfjuly2 = dfjuly1.reset_index()
print(dfjuly2)

x = dfjuly2['hourly']
yjul = dfjuly2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yjul, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Polskiej Organizacji Wojskowej - Diurnal Variation(July-2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  15.766667
# 1   01:30  17.266667
# 2   02:30  16.566667
# 3   03:30  16.433333
# 4   04:30  16.733333
# 5   05:30  16.833333
# 6   06:30  17.233333
# 7   07:30  17.600000
# 8   08:30  17.300000
# 9   09:30  16.233333
# 10  10:30  14.366667
# 11  11:30  12.500000
# 12  12:30  11.800000
# 13  13:30  11.266667
# 14  14:30  11.133333
# 15  15:30  10.966667
# 16  16:30  11.366667
# 17  17:30  11.966667
# 18  18:30  12.400000
# 19  19:30  12.233333
# 20  20:30  12.000000
# 21  21:30  11.533333
# 22  22:30  11.866667
# 23  23:30  13.300000

# %%
#august
dfaug = pd.read_csv("./Polskiej Organizacji Wojskowej/2021/Airly-report-2021-08-01T00_00-2021-08-31T00_00.csv")
newaug = dfaug["From;To;ID 31103 - PM2.5"].str.split(';', 2, expand = True)
dfaug["Date"] = newaug[0]
dfaug["PM2.5"] = newaug[2]
PMaug = []
PMaug = dfaug["PM2.5"].str.replace('"','')

for i in range(0,len(PMaug)):
    if PMaug[i] != '':
        PMaug[i] = int(PMaug[i])
    else:
        PMaug[i] = 0

Date8 = []
Date8 = dfaug["Date"]
Date8 = list(Date8)

Date8x = []
for j in range(0,len(Date8)):
    abc = Date8[j]
    abcd = abc.replace(abc[5:11], '')          
    Date8x.append(abcd)

zippedlist = list(zip(Date8x,PMaug))
dfaugust = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfaugust

dfaugust1 = dfaugust.groupby(['hourly']).mean()
dfaugust2 = dfaugust1.reset_index()
print(dfaugust2)

x = dfaugust2['hourly']
yaug = dfaugust2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yaug, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Polskiej Organizacji Wojskowej - Diurnal Variation(August-2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  14.133333
# 1   01:30  14.800000
# 2   02:30  14.766667
# 3   03:30  14.433333
# 4   04:30  14.533333
# 5   05:30  14.766667
# 6   06:30  15.100000
# 7   07:30  15.000000
# 8   08:30  14.833333
# 9   09:30  14.600000
# 10  10:30  13.500000
# 11  11:30  12.400000
# 12  12:30  11.000000
# 13  13:30   9.533333
# 14  14:30   8.266667
# 15  15:30   7.333333
# 16  16:30   7.233333
# 17  17:30   6.733333
# 18  18:30   6.533333
# 19  19:30   7.100000
# 20  20:30   7.733333
# 21  21:30   8.533333
# 22  22:30   9.800000
# 23  23:30  12.300000

# %%
#september
dfsep = pd.read_csv("./Polskiej Organizacji Wojskowej/2021/Airly-report-2021-09-01T00_00-2021-09-30T00_00.csv")
newsep = dfsep["From;To;ID 31103 - PM2.5"].str.split(';', 2, expand = True)
dfsep["Date"] = newsep[0]
dfsep["PM2.5"] = newsep[2]
PMsep = []
PMsep = dfsep["PM2.5"].str.replace('"','')

for i in range(0,len(PMsep)):
    if PMsep[i] != '':
        PMsep[i] = int(PMsep[i])
    else:
        PMsep[i] = 0

Date9 = []
Date9 = dfsep["Date"]
Date9 = list(Date9)

Date9x = []
for j in range(0,len(Date9)):
    abc = Date9[j]
    abcd = abc.replace(abc[5:11], '')          
    Date9x.append(abcd)

zippedlist = list(zip(Date9x,PMsep))
dfseptember = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfseptember

dfseptember1 = dfseptember.groupby(['hourly']).mean()
dfseptember2 = dfseptember1.reset_index()
print(dfseptember2)

x = dfseptember2['hourly']
ysep = dfseptember2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,ysep, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Polskiej Organizacji Wojskowej - Diurnal Variation(September-2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  23.344828
# 1   01:30  21.862069
# 2   02:30  20.724138
# 3   03:30  19.034483
# 4   04:30  18.689655
# 5   05:30  17.965517
# 6   06:30  17.310345
# 7   07:30  17.068966
# 8   08:30  16.931034
# 9   09:30  17.965517
# 10  10:30  16.758621
# 11  11:30  14.000000
# 12  12:30  10.896552
# 13  13:30   9.344828
# 14  14:30   9.103448
# 15  15:30   8.827586
# 16  16:30   8.827586
# 17  17:30   9.206897
# 18  18:30   9.689655
# 19  19:30   9.862069
# 20  20:30  10.689655
# 21  21:30  13.413793
# 22  22:30  18.793103
# 23  23:30  21.034483

# %%
#october
dfoct = pd.read_csv("./Polskiej Organizacji Wojskowej/2021/Airly-report-2021-10-01T00_00-2021-10-31T00_00.csv")
newoct = dfoct["From;To;ID 31103 - PM2.5"].str.split(';', 2, expand = True)
dfoct["Date"] = newoct[0]
dfoct["PM2.5"] = newoct[2]
PMoct = []
PMoct = dfoct["PM2.5"].str.replace('"','')

for i in range(0,len(PMoct)):
    if PMoct[i] != '':
        PMoct[i] = int(PMoct[i])
    else:
        PMoct[i] = 0

Date10 = []
Date10 = dfoct["Date"]
Date10 = list(Date10)

Date10x = []
for j in range(0,len(Date10)):
    abc = Date10[j]
    abcd = abc.replace(abc[5:11], '')          
    Date10x.append(abcd)

zippedlist = list(zip(Date10x,PMoct))
dfoctober = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfoctober

dfoctober1 = dfoctober.groupby(['hourly']).mean()
dfoctober2 = dfoctober1.reset_index()
print(dfoctober2)

x = dfoctober2['hourly']
yoct = dfoctober2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yoct, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Polskiej Organizacji Wojskowej - Diurnal Variation(October-2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  30.966667
# 1   01:30  31.533333
# 2   02:30  31.133333
# 3   03:30  30.600000
# 4   04:30  29.566667
# 5   05:30  27.866667
# 6   06:30  27.200000
# 7   07:30  26.633333
# 8   08:30  26.733333
# 9   09:30  27.766667
# 10  10:30  25.300000
# 11  11:30  23.566667
# 12  12:30  21.233333
# 13  13:30  19.800000
# 14  14:30  18.166667
# 15  15:30  17.100000
# 16  16:30  15.866667
# 17  17:30  15.066667
# 18  18:30  15.366667
# 19  19:30  16.800000
# 20  20:30  18.966667
# 21  21:30  24.500000
# 22  22:30  28.466667
# 23  23:30  31.166667

# %%
#november
dfnov = pd.read_csv("./Polskiej Organizacji Wojskowej/2021/Nov-POW.csv")
newnov = dfnov["From;To;ID 31103 - PM2.5"].str.split(';', 2, expand = True)
dfnov["Date"] = newnov[0]
dfnov["PM2.5"] = newnov[2]
PMnov = []
PMnov = dfnov["PM2.5"].str.replace('"','')

for i in range(0,len(PMnov)):
    if PMnov[i] != '':
        PMnov[i] = int(PMnov[i])
    else:
        PMnov[i] = 0

Date11 = []
Date11 = dfnov["Date"]
Date11 = list(Date11)

Date11x = []
for j in range(0,len(Date11)):
    abc = Date11[j]
    abcd = abc.replace(abc[5:11], '')          
    Date11x.append(abcd)

zippedlist = list(zip(Date11x,PMnov))
dfnovember = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfnovember

dfnovember1 = dfnovember.groupby(['hourly']).mean()
dfnovember2 = dfnovember1.reset_index()
print(dfnovember2)

x = dfnovember2['hourly']
ynov = dfnovember2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,ynov, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Polskiej Organizacji Wojskowej - Diurnal Variation(November-2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  34.000000
# 1   01:30  35.655172
# 2   02:30  34.310345
# 3   03:30  31.965517
# 4   04:30  31.103448
# 5   05:30  27.931034
# 6   06:30  26.344828
# 7   07:30  25.724138
# 8   08:30  25.758621
# 9   09:30  26.068966
# 10  10:30  26.103448
# 11  11:30  26.172414
# 12  12:30  26.206897
# 13  13:30  25.172414
# 14  14:30  24.793103
# 15  15:30  23.517241
# 16  16:30  23.689655
# 17  17:30  24.241379
# 18  18:30  24.241379
# 19  19:30  26.482759
# 20  20:30  29.068966
# 21  21:30  31.241379
# 22  22:30  31.413793
# 23  23:30  31.793103

# %%
#december
dfdec = pd.read_csv("./Polskiej Organizacji Wojskowej/2021/Dec-POW.csv")
newdec = dfdec["From;To;ID 31103 - PM2.5"].str.split(';', 2, expand = True)
dfdec["Date"] = newdec[0]
dfdec["PM2.5"] = newdec[2]
PMdec = []
PMdec = dfdec["PM2.5"].str.replace('"','')

for i in range(0,len(PMdec)):
    if PMdec[i] != '':
        PMdec[i] = int(PMdec[i])
    else:
        PMdec[i] = 0

Date12 = []
Date12 = dfdec["Date"]
Date12 = list(Date12)

Date12x = []
for j in range(0,len(Date12)):
    abc = Date12[j]
    abcd = abc.replace(abc[5:11], '')          
    Date12x.append(abcd)

zippedlist = list(zip(Date12x,PMdec))
dfdecember = pd.DataFrame(zippedlist, columns = ['hourly', 'conc'])
dfdecember

dfdecember1 = dfdecember.groupby(['hourly']).mean()
dfdecember2 = dfdecember1.reset_index()
print(dfdecember2)

x = dfdecember2['hourly']
ydec = dfdecember2['conc']
# print(x)
# print(y)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,ydec, linewidth = 3)
plt.xlabel("hour of the day")
plt.ylabel("PM2.5")
plt.title("Sensor Polskiej Organizacji Wojskowej - Diurnal Variation(December-2021)")
plt.show()
# Out:
#    hourly       conc
# 0   00:30  32.433333
# 1   01:30  32.900000
# 2   02:30  33.033333
# 3   03:30  31.933333
# 4   04:30  30.033333
# 5   05:30  28.666667
# 6   06:30  28.100000
# 7   07:30  26.800000
# 8   08:30  25.366667
# 9   09:30  25.133333
# 10  10:30  26.700000
# 11  11:30  27.433333
# 12  12:30  27.966667
# 13  13:30  26.333333
# 14  14:30  26.400000
# 15  15:30  26.166667
# 16  16:30  27.133333
# 17  17:30  26.300000
# 18  18:30  27.833333
# 19  19:30  28.466667
# 20  20:30  29.366667
# 21  21:30  30.266667
# 22  22:30  31.200000
# 23  23:30  32.566667

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(18, 12), dpi=150)
plt.plot(x,yjan, label = 'Jan')
plt.plot(x,yfeb, label = 'Feb')
plt.plot(x,ymar, label = 'Mar')
plt.plot(x,yapr, label = 'Apr')
plt.plot(x,ymay, label = 'May')
plt.plot(x,yjun, label = 'June')
plt.plot(x,yjul, label = 'July')
plt.plot(x,yaug, label = 'Aug')
plt.plot(x,ysep, label = 'Sept')
plt.plot(x,yoct, label = 'Oct')
plt.plot(x,ynov,color = 'm', label = 'Nov')
plt.plot(x,ydec,color = 'k', label = 'Dec')

plt.xlabel('Hour of the day')
plt.ylabel('PM2.5 conc')
plt.title('Diurnal variation(Sensor Polskiej Organizacji Wojskowej) - 2021')
plt.legend()
plt.show()
